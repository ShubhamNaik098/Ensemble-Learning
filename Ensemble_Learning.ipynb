# %% [markdown]
# **Theoratical Question**

# %% [markdown]
# Q1.Can we use Bagging for regression problems?

# %% [markdown]
# Ans.Yes, Bagging (Bootstrap Aggregating) can definitely be used for regression problems — not just classification.
#
# How It Works for Regression:
#
#     Bagging involves training multiple models (typically decision trees) on different bootstrap samples of the training data.
#
#     In regression, the predictions from each model are averaged to produce the final output (as opposed to voting in classification).

# %% [markdown]
# Q2.What is the difference between multiple model training and single model training?

# %% [markdown]
# Ans.The difference between multiple model training and single model training lies in how many models are used to make predictions and how their outputs are combined. Here's a breakdown:
#
# Single Model Training
#
# Multiple Model Training (Ensemble Learning)

# %% [markdown]
# Q3.Explain the concept of feature randomness in Random Forest.

# %% [markdown]
# Ans.Feature randomness in a Random Forest refers to the practice of randomly selecting a subset of features when determining the best split at each node in a decision tree. Unlike traditional decision trees that evaluate all available features to find the optimal split, Random Forest introduces randomness by considering only a limited number of randomly chosen features at each split. This technique reduces the correlation between the individual trees in the forest, increasing the diversity of the ensemble. As a result, the model becomes more robust and less prone to overfitting. Feature randomness helps ensure that each tree learns different patterns in the data, which enhances the overall generalization ability and predictive performance of the Random Forest model.

# %% [markdown]
# Q4.What is OOB (Out-of-Bag) Score?

# %% [markdown]
# Ans.The Out-of-Bag (OOB) Score is an internal performance estimate used in ensemble methods like Random Forest to evaluate how well the model generalizes, without needing a separate validation set.

# %% [markdown]
# Q5.How can you measure the importance of features in a Random Forest model?

# %% [markdown]
# Ans.You can measure feature importance in a Random Forest model using several methods, with the two most common being:
#
# 1.Mean Decrease in Impurity (MDI) – Default in Scikit-learn
#
# 2.Permutation Importance

# %% [markdown]
# Q6.Explain the working principle of a Bagging Classifier.

# %% [markdown]
# Ans.A Bagging Classifier (short for Bootstrap Aggregating) is an ensemble learning method that improves the accuracy and stability of machine learning models, particularly those prone to high variance like decision trees. The core idea is to train multiple models (called base learners) on different subsets of the training data, each generated by random sampling with replacement—a technique known as bootstrapping. Each base model is trained independently, and their predictions are aggregated to form the final output. For classification tasks, this aggregation is typically done through majority voting, while for regression tasks, it's done by averaging. By combining the predictions of diverse models trained on slightly different data, Bagging helps reduce overfitting and variance, leading to more robust and reliable performance on unseen data.

# %% [markdown]
# Q7. How do you evaluate a Bagging Classifier’s performance?

# %% [markdown]
# Ans.Evaluating a Bagging Classifier’s performance involves using standard machine learning metrics and validation techniques, with additional insights specific to ensemble models. Here's how it's typically done:
#
# 1.Train-Test Split or Cross-Validation:
#
# 2.Performance Metrics (for Classification):
#
# 3.Confusion Matrix:
#
# 4.Out-of-Bag (OOB) Score:
#
# 5.Learning Curves or Validation Curves:

# %% [markdown]
# Q8.How does a Bagging Regressor work?

# %% [markdown]
# Ans.A Bagging Regressor is an ensemble learning method that improves the performance and robustness of regression models by combining the predictions of multiple base regressors trained on different subsets of the data. The term "bagging" stands for Bootstrap Aggregating.
#
# How It Works:
#
# 1.Bootstrap Sampling:
#
#     The original training dataset is sampled multiple times with replacement to create several different training subsets.
#
#     Each subset is of the same size as the original dataset but may contain duplicate instances.
#
# 2.Train Base Estimators:
#
#     A regression model (e.g., Decision Tree Regressor) is trained independently on each bootstrap sample.
#
#     These models are referred to as base estimators or base learners.
#
# 3.Prediction Aggregation:
#
#     For a new data point, each base regressor makes a prediction.
#
#     The final prediction is the average of all individual predictions.

# %% [markdown]
# Q9.What is the main advantage of ensemble techniques?

# %% [markdown]
# Ans.The main advantage of ensemble techniques is that they combine the strengths of multiple models to produce more accurate, robust, and generalizable predictions than any single model alone.
#
# 1.Improved Accuracy:
#
#     By aggregating predictions (e.g., through voting or averaging), ensemble methods reduce the risk of overfitting or underfitting, leading to better overall performance.
#
# 2.Reduced Variance:
#
#     Techniques like bagging (e.g., Random Forest) decrease the model’s variance by training on different subsets of the data.
#
# 3.Reduced Bias:
#
#     Techniques like boosting (e.g., Gradient Boosting, AdaBoost) sequentially correct the errors of weak learners, reducing model bias.
#
# 4.Increased Stability:
#
#     Ensembles are less sensitive to fluctuations in the training data, making them more consistent and reliable.

# %% [markdown]
# Q10.What is the main challenge of ensemble methods?

# %% [markdown]
# Ans.Key challenges include:
#
# 1.Higher Computational Resources:
#
#     Training and predicting with multiple models requires more CPU/GPU time and memory, which can be expensive and slow, especially with large datasets or many base learners.
#
# 2.Reduced Interpretability:
#
#     Ensembles often act like “black boxes” because combining many models makes it harder to understand how individual features influence predictions.
#
# 3.Risk of Overfitting (if not managed properly):
#
#     Some ensemble methods, especially boosting, can overfit noisy data if hyperparameters aren’t tuned carefully.
#
# 4.Implementation Complexity:
#
#     Designing and tuning ensembles require more expertise, careful hyperparameter tuning, and validation strategies.

# %% [markdown]
# Q11.Explain the key idea behind ensemble techniques.

# %% [markdown]
# Ans.The key idea behind ensemble techniques is to combine multiple individual models (called base learners) to create a single, stronger predictive model that performs better than any one of the individual models alone.

# %% [markdown]
# Q12.What is a Random Forest Classifier?

# %% [markdown]
# Ans.A Random Forest Classifier is an ensemble learning method used for classification tasks that builds multiple decision trees and combines their predictions to improve accuracy, robustness, and generalization.

# %% [markdown]
# Q13.What are the main types of ensemble techniques?

# %% [markdown]
# Ans.The main types of ensemble techniques are:
#
# 1.Bagging (Bootstrap Aggregating)
#
#     Builds multiple models independently using different random subsets (with replacement) of the training data.
#
#     Combines predictions by averaging (regression) or majority voting (classification).
#
#     Example: Random Forest.
#
#     Goal: Reduce variance and prevent overfitting.
#
# 2.Boosting
#
#     Builds models sequentially, where each new model focuses on correcting errors made by previous ones.
#
#     Combines predictions by weighted sum.
#
#     Examples: AdaBoost, Gradient Boosting, XGBoost, LightGBM.
#
#     Goal: Reduce bias and improve accuracy.
#
# 3.Stacking (Stacked Generalization)
#
#     Combines multiple different base models (could be different algorithms).
#
#     Uses a meta-model to learn how to best combine base model predictions.
#
#     Goal: Leverage strengths of diverse models to improve performance.

# %% [markdown]
# Q14.What is ensemble learning in machine learning?

# %% [markdown]
# Ans.Ensemble learning in machine learning is a technique where multiple models (called base learners) are trained and combined to solve the same problem with the goal of achieving better overall performance than any single model alone.

# %% [markdown]
# Q15.When should we avoid using ensemble methods?

# %% [markdown]
# Ans.You should consider avoiding ensemble methods in the following situations:
#
# 1.When Interpretability Is Crucial
#
#     Ensembles, especially complex ones like Random Forests or Gradient Boosting, are often “black boxes” and hard to interpret compared to simpler models like linear regression or decision trees.
#
# 2.Limited Computational Resources
#
#     Ensembles require more computation time and memory for training and prediction. If you have tight constraints on hardware or need very fast predictions, simpler models may be better.
#
# 3.Small Datasets
#
#     Ensembles need sufficient data to train multiple diverse models effectively. On very small datasets, ensembles might overfit or provide little benefit over simple models.

# %% [markdown]
# Q16. How does Bagging help in reducing overfitting?

# %% [markdown]
# Ans.Bagging (Bootstrap Aggregating) helps reduce overfitting primarily by reducing the variance of unstable models like decision trees through averaging multiple diverse models trained on different subsets of the data.

# %% [markdown]
# Q17. Why is Random Forest better than a single Decision Tree?

# %% [markdown]
# Ans.Random Forest is generally better than a single Decision Tree because it overcomes many limitations of a single tree by combining multiple trees to improve accuracy, robustness, and generalization.
#
# 1.Reduces Overfitting
#
#     A single decision tree often overfits the training data, capturing noise and specific patterns that don’t generalize well.
#
#     Random Forest builds many trees on different random samples and averages their predictions, which smooths out noise and reduces overfitting.
#
# 2.Introduces Feature Randomness
#
#     While building each tree, Random Forest selects a random subset of features to split on at each node.
#
#     This decorrelates the trees, increasing diversity among them, which further improves generalization and reduces variance.

# %% [markdown]
# Q18.What is the role of bootstrap sampling in Bagging?

# %% [markdown]
# Ans.Bootstrap sampling plays a central role in Bagging (Bootstrap Aggregating) by creating diverse training subsets for each base model. Here's its role explained:
#
# 1.Generating Different Training Sets:
#
#     Bootstrap sampling means drawing random samples with replacement from the original dataset to create new training sets (called bootstrap samples) of the same size as the original.
#
#     Because of replacement, some original data points may appear multiple times in a bootstrap sample, while others may be left out.
#
# 2.Introducing Diversity Among Base Models:
#
#     Each base learner in Bagging is trained on a different bootstrap sample.
#
#     This leads to diversity among models because each sees a slightly different subset of data, reducing correlation between models.
#
# 3.Reducing Variance and Overfitting:
#
#     By averaging predictions of multiple models trained on these varied samples, Bagging reduces the variance of the overall model.
#
#     This helps to smooth out noise and prevents any single model from overfitting peculiarities in the original training set.

# %% [markdown]
# Q19.What are some real-world applications of ensemble techniques?

# %% [markdown]
# Ans.Ensemble techniques are widely used across many real-world domains because they often improve prediction accuracy and robustness. Here are some common applications:
#
# 1.Finance
#
#     Credit scoring and risk assessment
#
#     Fraud detection
#
#     Stock market prediction
#
# 2.Healthcare
#
#     Disease diagnosis and prognosis
#
#     Medical image analysis
#
#     Predicting patient outcomes
#
# 3.Marketing and Customer Analytics
#
#     Customer churn prediction
#
#     Targeted advertising and recommendation systems
#
#     Sentiment analysis

# %% [markdown]
# Q20.What is the difference between Bagging and Boosting?

# %% [markdown]
# Ans.

# %% [markdown]
# Q21.Train a Bagging Classifier using Decision Trees on a sample dataset and print model accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

base_dt = DecisionTreeClassifier(random_state=42)

bagging_clf = BaggingClassifier(base_estimator=base_dt, n_estimators=50, random_state=42)

bagging_clf.fit(X_train, y_train)

y_pred = bagging_clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Bagging Classifier Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-43452c9f2a6b> in <cell line: 0>()
#      12 base_dt = DecisionTreeClassifier(random_state=42)
#      13
# ---> 14 bagging_clf = BaggingClassifier(base_estimator=base_dt, n_estimators=50, random_state=42)
#      15
#      16 bagging_clf.fit(X_train, y_train)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q22.Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE).

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=500, n_features=5, noise=10, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
base_dt = DecisionTreeRegressor(random_state=42)
bagging_reg = BaggingRegressor(base_estimator=base_dt, n_estimators=50, random_state=42)
bagging_reg.fit(X_train, y_train)
y_pred = bagging_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Bagging Regressor Mean Squared Error: {mse:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-5c050025e80e> in <cell line: 0>()
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#       9 base_dt = DecisionTreeRegressor(random_state=42)
# ---> 10 bagging_reg = BaggingRegressor(base_estimator=base_dt, n_estimators=50, random_state=42)
#      11 bagging_reg.fit(X_train, y_train)
#      12 y_pred = bagging_reg.predict(X_test)
#
# TypeError: BaggingRegressor.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q23.Train a Random Forest Classifier on the Breast Cancer dataset and print feature importance scores.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)

rf_clf.fit(X_train, y_train)

importances = rf_clf.feature_importances_

print("Feature Importances:")
for name, importance in zip(feature_names, importances):
    print(f"{name}: {importance:.4f}")
# Out:
# Feature Importances:
# mean radius: 0.0323
# mean texture: 0.0111
# mean perimeter: 0.0601
# mean area: 0.0538
# mean smoothness: 0.0062
# mean compactness: 0.0092
# mean concavity: 0.0806
# mean concave points: 0.1419
# mean symmetry: 0.0033
# mean fractal dimension: 0.0031
# radius error: 0.0164
# texture error: 0.0032
# perimeter error: 0.0118
# area error: 0.0295
# smoothness error: 0.0059
# compactness error: 0.0046
# concavity error: 0.0058
# concave points error: 0.0034
# symmetry error: 0.0040
# fractal dimension error: 0.0071
# worst radius: 0.0780
# worst texture: 0.0188
# worst perimeter: 0.0743
# worst area: 0.1182
# worst smoothness: 0.0118
# worst compactness: 0.0175
# worst concavity: 0.0411
# worst concave points: 0.1271
# worst symmetry: 0.0129
# worst fractal dimension: 0.0069

# %% [markdown]
# Q24.Train a Random Forest Regressor and compare its performance with a single Decision Tree.

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=500, n_features=5, noise=15, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

dt_reg = DecisionTreeRegressor(random_state=42)
dt_reg.fit(X_train, y_train)
y_pred_dt = dt_reg.predict(X_test)
mse_dt = mean_squared_error(y_test, y_pred_dt)

rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
rf_reg.fit(X_train, y_train)
y_pred_rf = rf_reg.predict(X_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)

print(f"Decision Tree Regressor MSE: {mse_dt:.4f}")
print(f"Random Forest Regressor MSE: {mse_rf:.4f}")
# Out:
# Decision Tree Regressor MSE: 2919.3744
# Random Forest Regressor MSE: 1099.6526

# %% [markdown]
# Q25.Compute the Out-of-Bag (OOB) Score for a Random Forest Classifier.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X, y = data.data, data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
rf_clf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
rf_clf.fit(X_train, y_train)
print(f"Out-of-Bag (OOB) Score: {rf_clf.oob_score_:.4f}")
# Out:
# Out-of-Bag (OOB) Score: 0.9548

# %% [markdown]
# Q26.Train a Bagging Classifier using SVM as a base estimator and print accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

svm_base = SVC(kernel='linear', probability=True, random_state=42)

bagging_clf = BaggingClassifier(base_estimator=svm_base, n_estimators=10, random_state=42)

bagging_clf.fit(X_train, y_train)

y_pred = bagging_clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Bagging Classifier Accuracy with SVM base estimator: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b2c6d9130bd2> in <cell line: 0>()
#      12 svm_base = SVC(kernel='linear', probability=True, random_state=42)
#      13
# ---> 14 bagging_clf = BaggingClassifier(base_estimator=svm_base, n_estimators=10, random_state=42)
#      15
#      16 bagging_clf.fit(X_train, y_train)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q27.Train a Random Forest Classifier with different numbers of trees and compare accuracy.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

n_trees_list = [1, 5, 10, 50, 100, 200]

print("Random Forest Classifier Accuracy for different number of trees:")

for n_trees in n_trees_list:

    rf_clf = RandomForestClassifier(n_estimators=n_trees, random_state=42)
    rf_clf.fit(X_train, y_train)


    y_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)

    print(f"Number of trees: {n_trees} --> Accuracy: {accuracy:.4f}")
# Out:
# Random Forest Classifier Accuracy for different number of trees:
# Number of trees: 1 --> Accuracy: 0.9474
# Number of trees: 5 --> Accuracy: 0.9649
# Number of trees: 10 --> Accuracy: 0.9649
# Number of trees: 50 --> Accuracy: 0.9708
# Number of trees: 100 --> Accuracy: 0.9708
# Number of trees: 200 --> Accuracy: 0.9708

# %% [markdown]
# Q28.Train a Bagging Classifier using Logistic Regression as a base estimator and print AUC score.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

log_reg = LogisticRegression(max_iter=1000, random_state=42)

bagging_clf = BaggingClassifier(base_estimator=log_reg, n_estimators=20, random_state=42)

bagging_clf.fit(X_train, y_train)

y_proba = bagging_clf.predict_proba(X_test)[:, 1]

auc_score = roc_auc_score(y_test, y_proba)
print(f"Bagging Classifier AUC score with Logistic Regression base estimator: {auc_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-76ff19904551> in <cell line: 0>()
#      12 log_reg = LogisticRegression(max_iter=1000, random_state=42)
#      13
# ---> 14 bagging_clf = BaggingClassifier(base_estimator=log_reg, n_estimators=20, random_state=42)
#      15
#      16 bagging_clf.fit(X_train, y_train)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q29.Train a Random Forest Regressor and analyze feature importance scores.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

data = fetch_california_housing()
X, y = data.data, data.target
feature_names = data.feature_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train, y_train)

importances = rf_regressor.feature_importances_

print("Feature Importances:")
for name, importance in zip(feature_names, importances):
    print(f"{name}: {importance:.4f}")
# Out:
# Feature Importances:
# MedInc: 0.5260
# HouseAge: 0.0547
# AveRooms: 0.0472
# AveBedrms: 0.0300
# Population: 0.0317
# AveOccup: 0.1382
# Latitude: 0.0861
# Longitude: 0.0861

# %% [markdown]
# Q30.Train an ensemble model using both Bagging and Random Forest and compare accuracy.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

base_dt = DecisionTreeClassifier(random_state=42)

bagging_clf = BaggingClassifier(base_estimator=base_dt, n_estimators=100, random_state=42)
bagging_clf.fit(X_train, y_train)
y_pred_bagging = bagging_clf.predict(X_test)
accuracy_bagging = accuracy_score(y_test, y_pred_bagging)

rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print(f"Bagging Classifier Accuracy: {accuracy_bagging:.4f}")
print(f"Random Forest Classifier Accuracy: {accuracy_rf:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-92612c23fc53> in <cell line: 0>()
#      12 base_dt = DecisionTreeClassifier(random_state=42)
#      13
# ---> 14 bagging_clf = BaggingClassifier(base_estimator=base_dt, n_estimators=100, random_state=42)
#      15 bagging_clf.fit(X_train, y_train)
#      16 y_pred_bagging = bagging_clf.predict(X_test)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q31.Train a Random Forest Classifier and tune hyperparameters using GridSearchCV.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

grid_search.fit(X_train, y_train)

print("Best Hyperparameters:", grid_search.best_params_)

best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy with Best Estimator: {accuracy:.4f}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Test Accuracy with Best Estimator: 0.9708

# %% [markdown]
# Q33.Train a Random Forest Classifier and analyze misclassified samples.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names
target_names = data.target_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=target_names))

misclassified_indices = np.where(y_pred != y_test)[0]
print(f"\nNumber of Misclassified Samples: {len(misclassified_indices)}")

X_test_df = pd.DataFrame(X_test, columns=feature_names)
X_test_df['Actual'] = y_test
X_test_df['Predicted'] = y_pred

print("\nMisclassified Samples:")
print(X_test_df.iloc[misclassified_indices])
# Out:
# Accuracy: 0.9707602339181286
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    malignant       0.98      0.94      0.96        63
#       benign       0.96      0.99      0.98       108
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
#
# Number of Misclassified Samples: 5
#
# Misclassified Samples:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 8          13.34         15.86           86.49      520.0          0.10780
# 20         13.80         15.79           90.43      584.1          0.10070
# 77         13.96         17.05           91.43      602.4          0.10960
# 82         14.48         21.46           94.25      648.2          0.09444
# 164        15.13         29.81           96.71      719.5          0.08320
#
# ...

# %% [markdown]
# Q34.Train a Bagging Classifier and compare its performance with a single Decision Tree Classifier.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

bagging = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging.fit(X_train, y_train)
y_pred_bagging = bagging.predict(X_test)

print("Single Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Bagging Classifier Accuracy:", accuracy_score(y_test, y_pred_bagging))

print("\nClassification Report - Decision Tree:\n", classification_report(y_test, y_pred_dt))
print("\nClassification Report - Bagging Classifier:\n", classification_report(y_test, y_pred_bagging))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3fb079005b11> in <cell line: 0>()
#      14 y_pred_dt = dt.predict(X_test)
#      15
# ---> 16 bagging = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
#      17 bagging.fit(X_train, y_train)
#      18 y_pred_bagging = bagging.predict(X_test)
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q35.Train a Random Forest Classifier and visualize the confusion matrix.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
labels = data.target_names

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Random Forest Classifier')
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.9707602339181286

# %% [markdown]
# Q36. Train a Stacking Classifier using Decision Trees, SVM, and Logistic Regression, and compare accuracy.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

estimators = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svm', SVC(probability=True, kernel='rbf', random_state=42))
]

final_estimator = LogisticRegression(random_state=42)

stack_model = StackingClassifier(estimators=estimators, final_estimator=final_estimator, cv=5)
stack_model.fit(X_train, y_train)

y_pred_stack = stack_model.predict(X_test)
print("Stacking Classifier Accuracy:", accuracy_score(y_test, y_pred_stack))

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))

svm = SVC(probability=True, kernel='rbf', random_state=42)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))

lr = LogisticRegression(max_iter=10000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Stacking Classifier Accuracy: 0.9707602339181286
# Decision Tree Accuracy: 0.9415204678362573
# SVM Accuracy: 0.935672514619883
# Logistic Regression Accuracy: 0.9766081871345029

# %% [markdown]
# Q37. Train a Random Forest Classifier and print the top 5 most important features.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

top_features = feature_importance_df.sort_values(by='Importance', ascending=False).head(5)
print("Top 5 Important Features in Random Forest Classifier:")
print(top_features.to_string(index=False))
# Out:
# Top 5 Important Features in Random Forest Classifier:
#              Feature  Importance
#  mean concave points    0.141934
# worst concave points    0.127136
#           worst area    0.118217
#       mean concavity    0.080557
#         worst radius    0.077975

# %% [markdown]
# Q38.Train a Bagging Classifier and evaluate performance using Precision, Recall, and F1-score.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

base_estimator = DecisionTreeClassifier(random_state=42)
bagging_model = BaggingClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)
bagging_model.fit(X_train, y_train)

y_pred = bagging_model.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=data.target_names))
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-be3c8417c4e8> in <cell line: 0>()
#      11
#      12 base_estimator = DecisionTreeClassifier(random_state=42)
# ---> 13 bagging_model = BaggingClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)
#      14 bagging_model.fit(X_train, y_train)
#      15
#
# TypeError: BaggingClassifier.__init__() got an unexpected keyword argument 'base_estimator'

# %% [markdown]
# Q39.Train a Random Forest Classifier and analyze the effect of max_depth on accuracy.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

depths = list(range(1, 21))
accuracies = []

for depth in depths:
    rf = RandomForestClassifier(max_depth=depth, random_state=42)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

plt.figure(figsize=(10, 6))
plt.plot(depths, accuracies, marker='o')
plt.title('Effect of max_depth on Random Forest Accuracy')
plt.xlabel('max_depth')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %% [markdown]
# Q40.Train a Bagging Regressor using different base estimators (DecisionTree and KNeighbors) and compare performance.

# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=1000, n_features=10, noise=0.3, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

tree = DecisionTreeRegressor(random_state=42)
knn = KNeighborsRegressor()

bagging_tree = BaggingRegressor(base_estimator=tree, n_estimators=50, random_state=42)
bagging_knn = BaggingRegressor(base_estimator=knn, n_estimators=50, random_state=42)

bagging_tree.fit(X_train, y_train)
bagging_knn.fit(X_train, y_train)

pred_tree = bagging_tree.predict(X_test)
pred_knn = bagging_knn.predict(X_test)

mse_tree = mean_squared_error(y_test, pred_tree)
mse_knn = mean_squared_error(y_test, pred_knn)

print("MSE with Decision Tree base estimator:", round(mse_tree, 2))
print("MSE with K-Nearest Neighbors base estimator:", round(mse_knn, 2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-eb802605f3d1> in <cell line: 0>()
#      14 knn = KNeighborsRegressor()
#      15
# ---> 16 bagging_tree = BaggingRegressor(base_estimator=tree, n_estimators=50, random_state=42)
#      17 bagging_knn = BaggingRegressor(base_estimator=knn, n_estimators=50, random_state=42)
#      18
#
# TypeError: BaggingRegressor.__init__() got an unexpected keyword argument 'base_estimator'
